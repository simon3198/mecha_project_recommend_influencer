# %%
import pandas as pd
from Naver_Blog_Crawler import NaverBlogCrawler

response1 = pd.read_csv('보석십자수 설문조사 결과.csv')
response2 = pd.read_csv('savejjjw.csv')
response = pd.concat([response1,response2])
response.drop(['Unnamed: 0'],inplace=True,axis='columns')
response.reset_index(drop=True,inplace=True)
response['rate'] = response['response score']/response['Max score']
link_list = response['Post URL'].tolist()
crawler = NaverBlogCrawler(_blog_url_list = link_list)
df = crawler.getPostDataFrame_blogUrls()
df
# Out:
# 99/99
#                                              Post URL  \
# 0   https://blog.naver.com/verachl?Redirect=Log&lo...
# 1   https://blog.naver.com/bbekimha?Redirect=Log&l...
# 2   https://blog.naver.com/dhsmf0?Redirect=Log&log...
# 3   https://blog.naver.com/mjpslove1?Redirect=Log&...
# 4   https://blog.naver.com/sujaeshop?Redirect=Log&...
# ..                                                ...
# 89  https://blog.naver.com/cosyj82?Redirect=Log&lo...
# 90  https://blog.naver.com/rothy2407?Redirect=Log&...
# 91  https://blog.naver.com/until79?Redirect=Log&lo...
# 92  https://blog.naver.com/goroming22?Redirect=Log...
# 93  https://blog.naver.com/forcetk?Redirect=Log&lo...
#
#                                                  Post Image num sticker num  \
# 0   세상에 하나 뿐인 유일무이 보석 십자수 만들어봤다~~~!!!​​보석십자수 3개 하고...         4           0
# 1   ​안녕하세요 :)​요즘 집에 있는 시간이 다들 많아지면서여러가지 시간 때우기 취미를...        26           0
# 2   우리집 말썽쟁이 남매들은 책 한권을 끝낼때마다 장난감을 하나씩 선물 받습니다. 그런...        18           0
# 3   저번에 아이러브페인팅에서 나온BTS 유화그리기를 했었는데 재밌고 예쁘고 했었거등요!...        16           0
# 4   안녕하세요! ​※ 중독주의 ※ 보석십자수 수재샵입니다!​​이번에 소개해드릴 제품은,...        14           2
# ..                                                ...       ...         ...
# 89  택배왔숑택배왔숑.주문한 지 하루만에 배송 온, 부지런한 육아용품 회사들.아직 덜 왔...        18           0
# 90  요즘 최대 관심사 이유식!!!​이유식이라는 새로운 장르를 열어보면서좀 더 안심할 수...        26           3
# 91  안녕하세요, 이웃님들!​시윤이 기저귀 무게 및 이유식 양 체크를 하기위해서다이소에서...        12           0
# 92  안녕하세요🙋중고거래에 중독된 밍기적입니다​강밍키(25세, 요리경력 1년의 프리랜서)...        33           0
# 93  안녕하세요 ​티갱입니다​​오늘은 한국 기업 카스 아시나요?​맥주 아닙니다 ㅎㅎ​CA...        26           7
#
#    gif num Paragraph num Comment num Video num  weekly viewer mean  \
# 0        0           137           0         0                25.4
# 1        1           577           0         1              4804.0
# 2        0           182           0         0               120.4
# 3        5           369           8         1              4422.0
# 4        0            60           0         0                61.8
# ..     ...           ...         ...       ...                 ...
# 89       0           103           0         0               186.4
# 90       0           186           0         0               181.8
# 91       0           123          90         0               431.2
# 92       0           267           3         0               322.0
# 93       0           366           8         0               647.8
#
#    Sympathy num AD        Posting Date Buddy num Total visit Blog category
# 0             2       2021. 5. 2. 6:57        50       86459            취미
# 1            14      2021. 5. 4. 23:01      5128     9958925         패션·미용
# 2             3     2020. 12. 27. 4:15       882      549533         일상·생각
# 3             2      2020. 5. 24. 1:58      1814     2010700         일상·생각
# 4             0     2021. 5. 28. 13:51       471      112432      인테리어·DIY
# ..          ... ..                 ...       ...         ...           ...
# 89            3      2021. 3. 9. 22:01       405      581905
# 90            1     2020. 7. 22. 11:44       309      514886
# 91            0      2021. 6. 14. 6:00      3051      151858         육아·결혼
# 92           13      2021. 1. 19. 0:57       202       68010         일상·생각
# 93            8     2020. 12. 7. 18:39       452      443633         일상·생각
#
# [94 rows x 15 columns]

# %%
df['Image num'] = pd.to_numeric(df['Image num'], errors='coerce')
df['sticker num'] = pd.to_numeric(df['sticker num'], errors='coerce')
df['gif num'] = pd.to_numeric(df['gif num'], errors='coerce')
df['Paragraph num'] = pd.to_numeric(df['Paragraph num'], errors='coerce')
df['Comment num'] = pd.to_numeric(df['Comment num'], errors='coerce')
df['Video num'] = pd.to_numeric(df['Video num'], errors='coerce')
df['Sympathy num'] = pd.to_numeric(df['Sympathy num'], errors='coerce')
df['Buddy num'] = pd.to_numeric(df['Buddy num'], errors='coerce')
df['Total visit'] = pd.to_numeric(df['Total visit'],errors='coerce')
df['rate'] = response['rate']
df['Video num'] = np.where(df['Video num']<1,0,1)
df['sym*par'] = df['Sympathy num']*df['Paragraph num']
df['sym*com']=df['Sympathy num']*df['Comment num']
# if df['Image num']!=0:
df['imgwrd']=df['Paragraph num']/df['Image num']

# %%
import math
import numpy as np
df['sym*par'] = df['Sympathy num']*df['Paragraph num']
# df['Total visit'] = df['Total visit'].astype(float)
# df['Total visit'] = np.log(df['Total visit'])
max_index = df['rate']>=0.66
min_index = df['rate']<=0.25
max_df = df[max_index]
min_df=df[min_index]

# %%
max_df = max_df.mean()
min_df = min_df.mean()

# %%
max_df/min_df
# Out:
# Image num              1.080375
# sticker num            1.277890
# gif num                1.003135
# Paragraph num          0.932730
# Comment num            1.192992
# Video num              0.948276
# weekly viewer mean     1.150625
# Sympathy num           1.031069
# Buddy num              1.319842
# Total visit            1.272029
# rate                  46.379310
# sym*par                1.049414
# dtype: float64

# %%
data = pd.read_csv('click.csv')
data.rename(columns={'Unnamed: 0':'id'},inplace=True)

# %%
blogger_list=[]
for i in data['id']:
    i = i.split('.')
    blogid = i[0]
    logno = i[1]
    link_ = f'https://blog.naver.com/{blogid}?Redirect=Log&logNo={logno}'
    blogger_list.append(link_)
blogger_list[:5]
# Out:
# ['https://blog.naver.com/kmc1307?Redirect=Log&logNo=221741823916',
#  'https://blog.naver.com/dhksrl0508?Redirect=Log&logNo=221699961868',
#  'https://blog.naver.com/kmc1307?Redirect=Log&logNo=221811255213',
#  'https://blog.naver.com/makermanhyeon?Redirect=Log&logNo=221876861551',
#  'https://blog.naver.com/chandong83?Redirect=Log&logNo=221212429360']

# %%
crawler1 = NaverBlogCrawler(_blog_url_list = blogger_list)
df = crawler1.getPostDataFrame_blogUrls()
df
df.drop(index=0,inplace=True)
# Out:
# 80/175no mainFrame error
# 87/175no mainFrame error
# 175/175

# %%
df['click'] = data['click']
df['Image num'] = pd.to_numeric(df['Image num'], errors='coerce')
df['sticker num'] = pd.to_numeric(df['sticker num'], errors='coerce')
df['gif num'] = pd.to_numeric(df['gif num'], errors='coerce')
df['Paragraph num'] = pd.to_numeric(df['Paragraph num'], errors='coerce')
df['Comment num'] = pd.to_numeric(df['Comment num'], errors='coerce')
df['Video num'] = pd.to_numeric(df['Video num'], errors='coerce')
df['Sympathy num'] = pd.to_numeric(df['Sympathy num'], errors='coerce')
df['Buddy num'] = pd.to_numeric(df['Buddy num'], errors='coerce')
df['Total visit'] = pd.to_numeric(df['Total visit'], errors='coerce')
df['click'] = pd.to_numeric(df['click'], errors='coerce')

# %%
df['click'].sort_values(ascending=False).head(50)
# Out:
# 1     1256
# 2     1128
# 3      816
# 4      774
# 5      704
# 6      464
# 7      389
# 8      371
# 9      368
# 10     340
# 11     334
# 12     306
# 13     264
# 14     262
# 15     246
# 16     222
# 17     211
# 18     201
# 19     195
# 20     177
# 21     168
# 22     166
# 23     152
# 24     135
# 25     131
# 26     124
# 27     119
# 28     115
# 29     114
# 30     114
# 31     112
# 32     108
# 33     106
# 34     105
# 35      98
# 36      96
# 37      96
# 38      96
# 39      93
# 40      88
# 41      87
# 42      80
# 43      79
# 44      71
# 45      70
# 46      65
# 47      64
# 48      60
# 49      57
# 50      53
# Name: click, dtype: int64

# %%
max_index = df['click']>=100
min_index = df['click']<=10
max_df = df[max_index]
min_df=df[min_index]

# %%
max_df = max_df.mean()
min_df = min_df.mean()

# %%
max_df / min_df
# Out:
# Image num              1.142936
# sticker num            0.226891
# gif num                0.058824
# Paragraph num          1.542716
# Comment num           44.647059
# Video num              1.200000
# weekly viewer mean    10.454569
# Sympathy num           3.924949
# Buddy num              9.723932
# Total visit           14.592374
# click                 45.365546
# dtype: float64

# %%
df.corr()
# Out:
#                     Image num  sticker num   gif num  Paragraph num  \
# Image num            1.000000     0.023896 -0.050364       0.421028
# sticker num          0.023896     1.000000  0.425833      -0.113056
# gif num             -0.050364     0.425833  1.000000      -0.041211
# Paragraph num        0.421028    -0.113056 -0.041211       1.000000
# Comment num          0.106089    -0.091862 -0.095287       0.039490
# Video num           -0.064989     0.036670  0.070430      -0.086328
# weekly viewer mean  -0.029895    -0.050865 -0.024358       0.020242
# Sympathy num         0.246636     0.042494  0.044133       0.104716
# Buddy num            0.011927    -0.101569 -0.081133       0.019554
# Total visit          0.016235    -0.104817 -0.082193       0.021676
# click                0.136921    -0.115430 -0.090344       0.220744
#
#                     Comment num  Video num  weekly viewer mean  Sympathy num  \
# Image num              0.106089  -0.064989           -0.029895      0.246636
# sticker num           -0.091862   0.036670           -0.050865      0.042494
# gif num               -0.095287   0.070430           -0.024358      0.044133
# Paragraph num          0.039490  -0.086328            0.020242      0.104716
# Comment num            1.000000  -0.193345            0.622799      0.637202
# Video num             -0.193345   1.000000           -0.079472     -0.095475
# weekly viewer mean     0.622799  -0.079472            1.000000      0.552070
# Sympathy num           0.637202  -0.095475            0.552070      1.000000
# Buddy num              0.635857  -0.094881            0.988196      0.555342
# Total visit            0.649313  -0.097240            0.979994      0.559668
# click                  0.496970  -0.136788            0.213683      0.477773
#
#                     Buddy num  Total visit     click
# Image num            0.011927     0.016235  0.136921
# sticker num         -0.101569    -0.104817 -0.115430
# gif num             -0.081133    -0.082193 -0.090344
# Paragraph num        0.019554     0.021676  0.220744
# Comment num          0.635857     0.649313  0.496970
# Video num           -0.094881    -0.097240 -0.136788
# weekly viewer mean   0.988196     0.979994  0.213683
# Sympathy num         0.555342     0.559668  0.477773
# Buddy num            1.000000     0.988976  0.224992
# Total visit          0.988976     1.000000  0.246075
# click                0.224992     0.246075  1.000000

# %%
df.describe()
# Out:
#         Image num  sticker num     gif num  Paragraph num  Comment num  \
# count  137.000000   137.000000  137.000000     137.000000   137.000000
# mean     6.744526     0.240876    0.182482     282.175182     5.029197
# std      6.495507     0.636229    0.867883     241.227708     9.934300
# min      0.000000     0.000000    0.000000      54.000000     0.000000
# 25%      2.000000     0.000000    0.000000     138.000000     0.000000
# 50%      5.000000     0.000000    0.000000     225.000000     0.000000
# 75%      8.000000     0.000000    0.000000     337.000000     5.000000
# max     37.000000     3.000000    6.000000    2020.000000    58.000000
#
#         Video num  weekly viewer mean  Sympathy num    Buddy num  \
# count  137.000000          137.000000    137.000000   137.000000
# mean     0.474453          734.630657      3.153285  1182.751825
# std      0.738443         1286.292975      4.063631  1913.042533
# min      0.000000            0.000000      0.000000     0.000000
# 25%      0.000000           68.400000      0.000000   244.000000
# 50%      0.000000          208.400000      2.000000   372.000000
# 75%      1.000000          462.400000      4.000000   612.000000
# max      5.000000         3570.800000     18.000000  5393.000000
#
#         Total visit        click
# count  1.370000e+02   137.000000
# mean   8.154367e+05    99.058394
# std    1.443180e+06   191.725323
# min    1.380000e+02     3.000000
# 25%    5.010100e+04    10.000000
# 50%    1.048350e+05    28.000000
# 75%    3.297430e+05    98.000000
# max    3.973456e+06  1256.000000

# %%
import matplotlib.pyplot as plt
# df.drop(index=0,inplace=True)
df['sym*par'] = df['Sympathy num']*df['Paragraph num']
df['sym*com']=df['Sympathy num']*df['Comment num']
# if df['Image num']!=0:
df['imgwrd']=df['Paragraph num']/df['Image num']
# else:
#     df['imgwrd']= 100

# %%
df.corr()
# Out:
#                     Image num  sticker num   gif num  Paragraph num  \
# Image num            1.000000     0.023896 -0.050364       0.421028
# sticker num          0.023896     1.000000  0.425833      -0.113056
# gif num             -0.050364     0.425833  1.000000      -0.041211
# Paragraph num        0.421028    -0.113056 -0.041211       1.000000
# Comment num          0.106089    -0.091862 -0.095287       0.039490
# Video num           -0.064989     0.036670  0.070430      -0.086328
# weekly viewer mean  -0.029895    -0.050865 -0.024358       0.020242
# Sympathy num         0.246636     0.042494  0.044133       0.104716
# Buddy num            0.011927    -0.101569 -0.081133       0.019554
# Total visit          0.016235    -0.104817 -0.082193       0.021676
# click                0.136921    -0.115430 -0.090344       0.220744
# sym*par              0.271097    -0.005549  0.003020       0.353488
# sym*com              0.130892    -0.029068 -0.069338       0.063834
# imgwrd              -0.355393    -0.122334 -0.038031       0.266400
#
#                     Comment num  Video num  weekly viewer mean  Sympathy num  \
# Image num              0.106089  -0.064989           -0.029895      0.246636
# sticker num           -0.091862   0.036670           -0.050865      0.042494
# gif num               -0.095287   0.070430           -0.024358      0.044133
# Paragraph num          0.039490  -0.086328            0.020242      0.104716
# Comment num            1.000000  -0.193345            0.622799      0.637202
# Video num             -0.193345   1.000000           -0.079472     -0.095475
# weekly viewer mean     0.622799  -0.079472            1.000000      0.552070
# Sympathy num           0.637202  -0.095475            0.552070      1.000000
# Buddy num              0.635857  -0.094881            0.988196      0.555342
# Total visit            0.649313  -0.097240            0.979994      0.559668
# click                  0.496970  -0.136788            0.213683      0.477773
# sym*par                0.478284  -0.151931            0.412113      0.845751
# sym*com                0.921118  -0.204322            0.605563      0.741831
# imgwrd                -0.016618  -0.026100            0.021371     -0.131558
#
#                     Buddy num  Total visit     click   sym*par   sym*com  \
# Image num            0.011927     0.016235  0.136921  0.271097  0.130892
# sticker num         -0.101569    -0.104817 -0.115430 -0.005549 -0.029068
# gif num             -0.081133    -0.082193 -0.090344  0.003020 -0.069338
# Paragraph num        0.019554     0.021676  0.220744  0.353488  0.063834
# Comment num          0.635857     0.649313  0.496970  0.478284  0.921118
# Video num           -0.094881    -0.097240 -0.136788 -0.151931 -0.204322
# weekly viewer mean   0.988196     0.979994  0.213683  0.412113  0.605563
# Sympathy num         0.555342     0.559668  0.477773  0.845751  0.741831
# Buddy num            1.000000     0.988976  0.224992  0.419682  0.614112
# Total visit          0.988976     1.000000  0.246075  0.422821  0.619661
# click                0.224992     0.246075  1.000000  0.589180  0.439279
# sym*par              0.419682     0.422821  0.589180  1.000000  0.581411
# sym*com              0.614112     0.619661  0.439279  0.581411  1.000000
# imgwrd               0.013806     0.022062  0.048298 -0.005755 -0.044151
#
#                       imgwrd
# Image num          -0.355393
# sticker num        -0.122334
# gif num            -0.038031
# Paragraph num       0.266400
# Comment num        -0.016618
# Video num          -0.026100
# weekly viewer mean  0.021371
# Sympathy num       -0.131558
# Buddy num           0.013806
# Total visit         0.022062
# click               0.048298
# sym*par            -0.005755
# sym*com            -0.044151
# imgwrd              1.000000

# %%
import math
import numpy as np
df['sym*par'] = df['Sympathy num']*df['Paragraph num']
# df['Total visit'] = df['Total visit'].astype(float)
# df['Total visit'] = np.log(df['Total visit'])
max_index = df['rate']>=0.66
min_index = df['rate']<=0.25
max_df = df[max_index]
min_df=df[min_index]
